# %% [markdown]
# Este código cria um arquivo chamado `meu_arquivo.py` no diretório atual do seu ambiente Colab. O conteúdo do arquivo será tudo o que estiver abaixo do comando `%%writefile`.
#
# Você pode verificar se o arquivo foi criado usando o seguinte comando:

# %%
pip install numpy

# %% [markdown]
# E para executar o arquivo Python que você acabou de criar, você pode usar o seguinte comando:
